# %%
# !pip3 install --upgrade tensorflow==2.7.0 
# !pip3 install --upgrade tensorflow-quantum 
# !pip3 install seaborn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.7.0 in /root/venv/lib/python3.9/site-packages (2.7.0)
# Requirement already satisfied: numpy>=1.14.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.23.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.1.2)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.7.0) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (14.0.6)
# Requirement already satisfied: protobuf>=3.9.2 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.7.0) (3.17.3)
# Requirement already satisfied: absl-py>=0.4.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (4.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.9/site-packages (from tensorflow==2.7.0) (0.40.0)
# Requirement already satisfied: six>=1.12.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.50.0)
# Requirement already satisfied: tensorboard~=2.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (2.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (2.0.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.7.0) (2.0.7)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /root/venv/lib/python3.9/site-packages (from tensorflow==2.7.0) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (3.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (0.27.0)
# Requirement already satisfied: wrapt>=1.11.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow==2.7.0) (1.14.1)
# Requirement already satisfied: setuptools>=41.0.0 in /root/venv/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (58.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /root/venv/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.18.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow==2.7.0) (2.28.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /root/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (5.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7.0) (3.4)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7.0) (3.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.7.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7.0) (3.2.2)
# Installing collected packages: MarkupSafe
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
# Successfully installed MarkupSafe-2.1.3
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorflow-quantum in /root/venv/lib/python3.9/site-packages (0.7.2)
# Requirement already satisfied: sympy==1.8 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (1.8)
# Requirement already satisfied: cirq-core==0.13.1 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (0.13.1)
# Requirement already satisfied: cirq-google>=0.13.1 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (0.13.1)
# Requirement already satisfied: google-api-core==1.21.0 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (1.21.0)
# Requirement already satisfied: google-auth==1.18.0 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (1.18.0)
# Requirement already satisfied: protobuf==3.17.3 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (3.17.3)
# Requirement already satisfied: googleapis-common-protos==1.52.0 in /root/venv/lib/python3.9/site-packages (from tensorflow-quantum) (1.52.0)
# Requirement already satisfied: matplotlib~=3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (3.6.0)
# Requirement already satisfied: sortedcontainers~=2.0 in /root/venv/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (2.4.0)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (1.2.5)
# Requirement already satisfied: networkx~=2.4 in /root/venv/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (2.8.8)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (1.9.3)
# Requirement already satisfied: numpy~=1.16 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (1.23.4)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (4.4.0)
# Requirement already satisfied: duet~=0.2.0 in /root/venv/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (0.2.9)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cirq-core==0.13.1->tensorflow-quantum) (4.64.1)
# Requirement already satisfied: six>=1.10.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from google-api-core==1.21.0->tensorflow-quantum) (1.16.0)
# Requirement already satisfied: setuptools>=34.0.0 in /root/venv/lib/python3.9/site-packages (from google-api-core==1.21.0->tensorflow-quantum) (58.1.0)
# Requirement already satisfied: pytz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core==1.21.0->tensorflow-quantum) (2022.5)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core==1.21.0->tensorflow-quantum) (2.28.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth==1.18.0->tensorflow-quantum) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth==1.18.0->tensorflow-quantum) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /root/venv/lib/python3.9/site-packages (from google-auth==1.18.0->tensorflow-quantum) (4.2.4)
# Requirement already satisfied: mpmath>=0.19 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sympy==1.8->tensorflow-quantum) (1.2.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core==1.21.0->tensorflow-quantum) (1.50.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (21.3)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==0.13.1->tensorflow-quantum) (9.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth==1.18.0->tensorflow-quantum) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.21.0->tensorflow-quantum) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.21.0->tensorflow-quantum) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.21.0->tensorflow-quantum) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core==1.21.0->tensorflow-quantum) (2.1.1)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from seaborn) (1.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.5)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# Update package resources to account for version changes.
import importlib, pkg_resources
importlib.reload(pkg_resources)
# Out:
# <module 'pkg_resources' from '/root/venv/lib/python3.9/site-packages/pkg_resources/__init__.py'>

# %%
import tensorflow as tf
import tensorflow_quantum as tfq

import cirq
import sympy
import numpy as np

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %%
qubit = cirq.GridQubit(0, 0)

# Define some circuits.
circuit1 = cirq.Circuit(cirq.X(qubit))
circuit2 = cirq.Circuit(cirq.H(qubit))

# Convert to a tensor.
input_circuit_tensor = tfq.convert_to_tensor([circuit1, circuit2])

# Define a circuit that we want to append
y_circuit = cirq.Circuit(cirq.Y(qubit))

# Instantiate our layer
y_appender = tfq.layers.AddCircuit()

# Run our circuit tensor through the layer and save the output.
output_circuit_tensor = y_appender(input_circuit_tensor, append=y_circuit)

# %%
print(tfq.from_tensor(input_circuit_tensor))
# Out:
# [cirq.Circuit([
#      cirq.Moment(
#          cirq.X(cirq.GridQubit(0, 0)),
#      ),
#  ])
#  cirq.Circuit([
#      cirq.Moment(
#          cirq.H(cirq.GridQubit(0, 0)),
#      ),
#  ])                                   ]

# %%
print(tfq.from_tensor(output_circuit_tensor))
# Out:
# [cirq.Circuit([
#      cirq.Moment(
#          cirq.X(cirq.GridQubit(0, 0)),
#      ),
#      cirq.Moment(
#          cirq.Y(cirq.GridQubit(0, 0)),
#      ),
#  ])
#  cirq.Circuit([
#      cirq.Moment(
#          cirq.H(cirq.GridQubit(0, 0)),
#      ),
#      cirq.Moment(
#          cirq.Y(cirq.GridQubit(0, 0)),
#      ),
#  ])                                   ]

# %%
def generate_data(qubits):
    """Generate training and testing data."""
    n_rounds = 20  # Produces n_rounds * n_qubits datapoints.
    excitations = []
    labels = []
    for n in range(n_rounds):
        for bit in qubits:
            rng = np.random.uniform(-np.pi, np.pi)
            excitations.append(cirq.Circuit(cirq.rx(rng)(bit)))
            labels.append(1 if (-np.pi / 2) <= rng <= (np.pi / 2) else -1)

    split_ind = int(len(excitations) * 0.7)
    train_excitations = excitations[:split_ind]
    test_excitations = excitations[split_ind:]

    train_labels = labels[:split_ind]
    test_labels = labels[split_ind:]

    return tfq.convert_to_tensor(train_excitations), np.array(train_labels), \
        tfq.convert_to_tensor(test_excitations), np.array(test_labels)

# %%
sample_points, sample_labels, _, __ = generate_data(cirq.GridQubit.rect(1, 4))
print('Input:', tfq.from_tensor(sample_points)[0], 'Output:', sample_labels[0])
print('Input:', tfq.from_tensor(sample_points)[1], 'Output:', sample_labels[1])
# Out:
# Input: (0, 0): ───X^0.559─── Output: -1
# Input: (0, 1): ───X^-0.513─── Output: -1

# %%
def cluster_state_circuit(bits):
    """Return a cluster state on the qubits in `bits`."""
    circuit = cirq.Circuit()
    circuit.append(cirq.H.on_each(bits))
    for this_bit, next_bit in zip(bits, bits[1:] + [bits[0]]):
        circuit.append(cirq.CZ(this_bit, next_bit))
    return circuit

# %%
SVGCircuit(cluster_state_circuit(cirq.GridQubit.rect(1, 4)))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
def one_qubit_unitary(bit, symbols):
    """Make a Cirq circuit enacting a rotation of the bloch sphere about the X,
    Y and Z axis, that depends on the values in `symbols`.
    """
    return cirq.Circuit(
        cirq.X(bit)**symbols[0],
        cirq.Y(bit)**symbols[1],
        cirq.Z(bit)**symbols[2])


def two_qubit_unitary(bits, symbols):
    """Make a Cirq circuit that creates an arbitrary two qubit unitary."""
    circuit = cirq.Circuit()
    circuit += one_qubit_unitary(bits[0], symbols[0:3])
    circuit += one_qubit_unitary(bits[1], symbols[3:6])
    circuit += [cirq.ZZ(*bits)**symbols[6]]
    circuit += [cirq.YY(*bits)**symbols[7]]
    circuit += [cirq.XX(*bits)**symbols[8]]
    circuit += one_qubit_unitary(bits[0], symbols[9:12])
    circuit += one_qubit_unitary(bits[1], symbols[12:])
    return circuit


def two_qubit_pool(source_qubit, sink_qubit, symbols):
    """Make a Cirq circuit to do a parameterized 'pooling' operation, which
    attempts to reduce entanglement down from two qubits to just one."""
    pool_circuit = cirq.Circuit()
    sink_basis_selector = one_qubit_unitary(sink_qubit, symbols[0:3])
    source_basis_selector = one_qubit_unitary(source_qubit, symbols[3:6])
    pool_circuit.append(sink_basis_selector)
    pool_circuit.append(source_basis_selector)
    pool_circuit.append(cirq.CNOT(control=source_qubit, target=sink_qubit))
    pool_circuit.append(sink_basis_selector**-1)
    return pool_circuit

# %%
SVGCircuit(one_qubit_unitary(cirq.GridQubit(0, 0), sympy.symbols('x0:3')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
SVGCircuit(two_qubit_unitary(cirq.GridQubit.rect(1, 2), sympy.symbols('x0:15')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
SVGCircuit(two_qubit_pool(*cirq.GridQubit.rect(1, 2), sympy.symbols('x0:6')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
def quantum_conv_circuit(bits, symbols):
    """Quantum Convolution Layer following the above diagram.
    Return a Cirq circuit with the cascade of `two_qubit_unitary` applied
    to all pairs of qubits in `bits` as in the diagram above.
    """
    circuit = cirq.Circuit()
    for first, second in zip(bits[0::2], bits[1::2]):
        circuit += two_qubit_unitary([first, second], symbols)
    for first, second in zip(bits[1::2], bits[2::2] + [bits[0]]):
        circuit += two_qubit_unitary([first, second], symbols)
    return circuit

# %%
SVGCircuit(
    quantum_conv_circuit(cirq.GridQubit.rect(1, 8), sympy.symbols('x0:15')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
def quantum_pool_circuit(source_bits, sink_bits, symbols):
    """A layer that specifies a quantum pooling operation.
    A Quantum pool tries to learn to pool the relevant information from two
    qubits onto 1.
    """
    circuit = cirq.Circuit()
    for source, sink in zip(source_bits, sink_bits):
        circuit += two_qubit_pool(source, sink, symbols)
    return circuit

# %%
test_bits = cirq.GridQubit.rect(1, 8)

SVGCircuit(
    quantum_pool_circuit(test_bits[:4], test_bits[4:], sympy.symbols('x0:6')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
def create_model_circuit(qubits):
    """Create sequence of alternating convolution and pooling operators 
    which gradually shrink over time."""
    model_circuit = cirq.Circuit()
    symbols = sympy.symbols('qconv0:63')
    # Cirq uses sympy.Symbols to map learnable variables. TensorFlow Quantum
    # scans incoming circuits and replaces these with TensorFlow variables.
    model_circuit += quantum_conv_circuit(qubits, symbols[0:15])
    model_circuit += quantum_pool_circuit(qubits[:4], qubits[4:],
                                          symbols[15:21])
    model_circuit += quantum_conv_circuit(qubits[4:], symbols[21:36])
    model_circuit += quantum_pool_circuit(qubits[4:6], qubits[6:],
                                          symbols[36:42])
    model_circuit += quantum_conv_circuit(qubits[6:], symbols[42:57])
    model_circuit += quantum_pool_circuit([qubits[6]], [qubits[7]],
                                          symbols[57:63])
    return model_circuit


# Create our qubits and readout operators in Cirq.
cluster_state_bits = cirq.GridQubit.rect(1, 8)
readout_operators = cirq.Z(cluster_state_bits[-1])

# Build a sequential model enacting the logic in 1.3 of this notebook.
# Here you are making the static cluster state prep as a part of the AddCircuit and the
# "quantum datapoints" are coming in the form of excitation
excitation_input = tf.keras.Input(shape=(), dtype=tf.dtypes.string)
cluster_state = tfq.layers.AddCircuit()(
    excitation_input, prepend=cluster_state_circuit(cluster_state_bits))

quantum_model = tfq.layers.PQC(create_model_circuit(cluster_state_bits),
                               readout_operators)(cluster_state)

qcnn_model = tf.keras.Model(inputs=[excitation_input], outputs=[quantum_model])

# Show the keras plot of the model
tf.keras.utils.plot_model(qcnn_model,
                          show_shapes=True,
                          show_layer_names=False,
                          dpi=70)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
# Generate some training data.
train_excitations, train_labels, test_excitations, test_labels = generate_data(
    cluster_state_bits)


# Custom accuracy metric.
@tf.function
def custom_accuracy(y_true, y_pred):
    y_true = tf.squeeze(y_true)
    y_pred = tf.map_fn(lambda x: 1.0 if x >= 0 else -1.0, y_pred)
    return tf.keras.backend.mean(tf.keras.backend.equal(y_true, y_pred))


qcnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
                   loss=tf.losses.mse,
                   metrics=[custom_accuracy])

history = qcnn_model.fit(x=train_excitations,
                         y=train_labels,
                         batch_size=16,
                         epochs=25,
                         verbose=1,
                         validation_data=(test_excitations, test_labels))
# Out:
# Epoch 1/25
# 7/7 [==============================] - 18s 2s/step - loss: 0.8459 - custom_accuracy: 0.7768 - val_loss: 0.8858 - val_custom_accuracy: 0.6250
# Epoch 2/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.7813 - custom_accuracy: 0.7857 - val_loss: 0.8441 - val_custom_accuracy: 0.7292
# Epoch 3/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.7033 - custom_accuracy: 0.8036 - val_loss: 0.8214 - val_custom_accuracy: 0.7083
# Epoch 4/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.6877 - custom_accuracy: 0.8304 - val_loss: 0.7535 - val_custom_accuracy: 0.7708
# Epoch 5/25
# 7/7 [==============================] - 12s 2s/step - loss: 0.6561 - custom_accuracy: 0.8482 - val_loss: 0.7266 - val_custom_accuracy: 0.8333
# Epoch 6/25
# 7/7 [==============================] - 11s 2s/step - loss: 0.6535 - custom_accuracy: 0.8214 - val_loss: 0.7145 - val_custom_accuracy: 0.8333
# Epoch 7/25
# 7/7 [==============================] - 10s 2s/step - loss: 0.6408 - custom_accuracy: 0.8393 - val_loss: 0.6663 - val_custom_accuracy: 0.8958
# Epoch 8/25
# 7/7 [==============================] - 10s 2s/step - loss: 0.6471 - custom_accuracy: 0.8036 - val_loss: 0.6186 - val_custom_accuracy: 0.8542
# Epoch 9/25
# 7/7 [==============================] - 7s 1s/step - loss: 0.5961 - custom_accuracy: 0.8482 - val_loss: 0.5954 - val_custom_accuracy: 0.8333
# Epoch 10/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.5708 - custom_accuracy: 0.8661 - val_loss: 0.5531 - val_custom_accuracy: 0.8333
# Epoch 11/25
# 7/7 [==============================] - 11s 2s/step - loss: 0.5405 - custom_accuracy: 0.8750 - val_loss: 0.5422 - val_custom_accuracy: 0.8125
# Epoch 12/25
# 7/7 [==============================] - 11s 2s/step - loss: 0.5649 - custom_accuracy: 0.8482 - val_loss: 0.5210 - val_custom_accuracy: 0.8542
# Epoch 13/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.6070 - custom_accuracy: 0.8661 - val_loss: 0.5214 - val_custom_accuracy: 0.8125
# Epoch 14/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.5911 - custom_accuracy: 0.8036 - val_loss: 0.5297 - val_custom_accuracy: 0.8750
# Epoch 15/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.5881 - custom_accuracy: 0.8571 - val_loss: 0.5095 - val_custom_accuracy: 0.8542
# Epoch 16/25
# 7/7 [==============================] - 7s 1s/step - loss: 0.5267 - custom_accuracy: 0.8571 - val_loss: 0.5130 - val_custom_accuracy: 0.8750
# Epoch 17/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.5479 - custom_accuracy: 0.8393 - val_loss: 0.5032 - val_custom_accuracy: 0.8542
# Epoch 18/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.5508 - custom_accuracy: 0.8393 - val_loss: 0.5015 - val_custom_accuracy: 0.8542
# Epoch 19/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.5473 - custom_accuracy: 0.8750 - val_loss: 0.5462 - val_custom_accuracy: 0.8542
# Epoch 20/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.5376 - custom_accuracy: 0.8661 - val_loss: 0.5252 - val_custom_accuracy: 0.8750
# Epoch 21/25
# 7/7 [==============================] - 7s 966ms/step - loss: 0.5275 - custom_accuracy: 0.8839 - val_loss: 0.5262 - val_custom_accuracy: 0.8542
# Epoch 22/25
# 7/7 [==============================] - 7s 1s/step - loss: 0.5293 - custom_accuracy: 0.8571 - val_loss: 0.5111 - val_custom_accuracy: 0.9167
# Epoch 23/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.5128 - custom_accuracy: 0.8929 - val_loss: 0.4777 - val_custom_accuracy: 0.8542
# Epoch 24/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.5044 - custom_accuracy: 0.8661 - val_loss: 0.4762 - val_custom_accuracy: 0.8750
# Epoch 25/25
# 7/7 [==============================] - 6s 882ms/step - loss: 0.4907 - custom_accuracy: 0.8661 - val_loss: 0.4831 - val_custom_accuracy: 0.8333

# %%
plt.plot(history.history['loss'][1:], label='Training')
plt.plot(history.history['val_loss'][1:], label='Validation')
plt.title('Training a Quantum CNN to Detect Excited Cluster States')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# 1-local operators to read out
readouts = [cirq.Z(bit) for bit in cluster_state_bits[4:]]


def multi_readout_model_circuit(qubits):
    """Make a model circuit with less quantum pool and conv operations."""
    model_circuit = cirq.Circuit()
    symbols = sympy.symbols('qconv0:21')
    model_circuit += quantum_conv_circuit(qubits, symbols[0:15])
    model_circuit += quantum_pool_circuit(qubits[:4], qubits[4:],
                                          symbols[15:21])
    return model_circuit


# Build a model enacting the logic in 2.1 of this notebook.
excitation_input_dual = tf.keras.Input(shape=(), dtype=tf.dtypes.string)

cluster_state_dual = tfq.layers.AddCircuit()(
    excitation_input_dual, prepend=cluster_state_circuit(cluster_state_bits))

quantum_model_dual = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_dual)

d1_dual = tf.keras.layers.Dense(8)(quantum_model_dual)

d2_dual = tf.keras.layers.Dense(1)(d1_dual)

hybrid_model = tf.keras.Model(inputs=[excitation_input_dual], outputs=[d2_dual])

# Display the model architecture
tf.keras.utils.plot_model(hybrid_model,
                          show_shapes=True,
                          show_layer_names=False,
                          dpi=70)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
hybrid_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
                     loss=tf.losses.mse,
                     metrics=[custom_accuracy])

hybrid_history = hybrid_model.fit(x=train_excitations,
                                  y=train_labels,
                                  batch_size=16,
                                  epochs=25,
                                  verbose=1,
                                  validation_data=(test_excitations,
                                                   test_labels))
# Out:
# Epoch 1/25
# 7/7 [==============================] - 9s 863ms/step - loss: 0.9890 - custom_accuracy: 0.5000 - val_loss: 0.8636 - val_custom_accuracy: 0.5208
# Epoch 2/25
# 7/7 [==============================] - 5s 667ms/step - loss: 0.6546 - custom_accuracy: 0.7500 - val_loss: 0.4335 - val_custom_accuracy: 0.8750
# Epoch 3/25
# 7/7 [==============================] - 5s 767ms/step - loss: 0.2985 - custom_accuracy: 0.8929 - val_loss: 0.2731 - val_custom_accuracy: 0.9167
# Epoch 4/25
# 7/7 [==============================] - 5s 752ms/step - loss: 0.1978 - custom_accuracy: 0.9464 - val_loss: 0.1901 - val_custom_accuracy: 0.9792
# Epoch 5/25
# 7/7 [==============================] - 5s 735ms/step - loss: 0.2043 - custom_accuracy: 0.9732 - val_loss: 0.1859 - val_custom_accuracy: 0.9583
# Epoch 6/25
# 7/7 [==============================] - 6s 801ms/step - loss: 0.1827 - custom_accuracy: 0.9821 - val_loss: 0.1920 - val_custom_accuracy: 0.9792
# Epoch 7/25
# 7/7 [==============================] - 5s 802ms/step - loss: 0.1764 - custom_accuracy: 0.9821 - val_loss: 0.2192 - val_custom_accuracy: 0.9583
# Epoch 8/25
# 7/7 [==============================] - 6s 965ms/step - loss: 0.1835 - custom_accuracy: 0.9732 - val_loss: 0.2105 - val_custom_accuracy: 0.9375
# Epoch 9/25
# 7/7 [==============================] - 5s 768ms/step - loss: 0.1734 - custom_accuracy: 0.9821 - val_loss: 0.1849 - val_custom_accuracy: 0.9583
# Epoch 10/25
# 7/7 [==============================] - 6s 914ms/step - loss: 0.1749 - custom_accuracy: 0.9821 - val_loss: 0.1977 - val_custom_accuracy: 0.9375
# Epoch 11/25
# 7/7 [==============================] - 4s 635ms/step - loss: 0.1697 - custom_accuracy: 0.9911 - val_loss: 0.1955 - val_custom_accuracy: 0.9583
# Epoch 12/25
# 7/7 [==============================] - 5s 734ms/step - loss: 0.1718 - custom_accuracy: 1.0000 - val_loss: 0.2020 - val_custom_accuracy: 0.9792
# Epoch 13/25
# 7/7 [==============================] - 6s 935ms/step - loss: 0.2119 - custom_accuracy: 0.9643 - val_loss: 0.2214 - val_custom_accuracy: 0.9583
# Epoch 14/25
# 7/7 [==============================] - 5s 735ms/step - loss: 0.1690 - custom_accuracy: 0.9732 - val_loss: 0.2265 - val_custom_accuracy: 0.9375
# Epoch 15/25
# 7/7 [==============================] - 6s 951ms/step - loss: 0.1923 - custom_accuracy: 0.9911 - val_loss: 0.2457 - val_custom_accuracy: 0.9167
# Epoch 16/25
# 7/7 [==============================] - 6s 870ms/step - loss: 0.2089 - custom_accuracy: 0.9821 - val_loss: 0.2211 - val_custom_accuracy: 0.9375
# Epoch 17/25
# 7/7 [==============================] - 5s 701ms/step - loss: 0.2053 - custom_accuracy: 0.9732 - val_loss: 0.2313 - val_custom_accuracy: 0.9375
# Epoch 18/25
# 7/7 [==============================] - 6s 817ms/step - loss: 0.1825 - custom_accuracy: 0.9732 - val_loss: 0.2032 - val_custom_accuracy: 0.9792
# Epoch 19/25
# 7/7 [==============================] - 5s 803ms/step - loss: 0.1892 - custom_accuracy: 0.9732 - val_loss: 0.2210 - val_custom_accuracy: 0.8958
# Epoch 20/25
# 7/7 [==============================] - 6s 836ms/step - loss: 0.1822 - custom_accuracy: 0.9732 - val_loss: 0.1973 - val_custom_accuracy: 0.9792
# Epoch 21/25
# 7/7 [==============================] - 5s 786ms/step - loss: 0.1635 - custom_accuracy: 1.0000 - val_loss: 0.2104 - val_custom_accuracy: 0.9167
# Epoch 22/25
# 7/7 [==============================] - 5s 767ms/step - loss: 0.1675 - custom_accuracy: 0.9911 - val_loss: 0.1915 - val_custom_accuracy: 0.9583
# Epoch 23/25
# 7/7 [==============================] - 5s 767ms/step - loss: 0.1708 - custom_accuracy: 0.9732 - val_loss: 0.2249 - val_custom_accuracy: 0.9375
# Epoch 24/25
# 7/7 [==============================] - 6s 886ms/step - loss: 0.1833 - custom_accuracy: 0.9911 - val_loss: 0.1920 - val_custom_accuracy: 0.9583
# Epoch 25/25
# 7/7 [==============================] - 4s 584ms/step - loss: 0.1635 - custom_accuracy: 0.9821 - val_loss: 0.2078 - val_custom_accuracy: 0.9167

# %%
plt.plot(history.history['val_custom_accuracy'], label='QCNN')
plt.plot(hybrid_history.history['val_custom_accuracy'], label='Hybrid CNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()

# %%
excitation_input_multi = tf.keras.Input(shape=(), dtype=tf.dtypes.string)

cluster_state_multi = tfq.layers.AddCircuit()(
    excitation_input_multi, prepend=cluster_state_circuit(cluster_state_bits))

# apply 3 different filters and measure expectation values

quantum_model_multi1 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

quantum_model_multi2 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

quantum_model_multi3 = tfq.layers.PQC(
    multi_readout_model_circuit(cluster_state_bits),
    readouts)(cluster_state_multi)

# concatenate outputs and feed into a small classical NN
concat_out = tf.keras.layers.concatenate(
    [quantum_model_multi1, quantum_model_multi2, quantum_model_multi3])

dense_1 = tf.keras.layers.Dense(8)(concat_out)

dense_2 = tf.keras.layers.Dense(1)(dense_1)

multi_qconv_model = tf.keras.Model(inputs=[excitation_input_multi],
                                   outputs=[dense_2])

# Display the model architecture
tf.keras.utils.plot_model(multi_qconv_model,
                          show_shapes=True,
                          show_layer_names=True,
                          dpi=70)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
multi_qconv_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),
    loss=tf.losses.mse,
    metrics=[custom_accuracy])

multi_qconv_history = multi_qconv_model.fit(x=train_excitations,
                                            y=train_labels,
                                            batch_size=16,
                                            epochs=25,
                                            verbose=1,
                                            validation_data=(test_excitations,
                                                             test_labels))
# Out:
# Epoch 1/25
# 7/7 [==============================] - 18s 2s/step - loss: 0.8209 - custom_accuracy: 0.6250 - val_loss: 0.5070 - val_custom_accuracy: 0.8125
# Epoch 2/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.2705 - custom_accuracy: 0.9375 - val_loss: 0.3053 - val_custom_accuracy: 0.9167
# Epoch 3/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.2335 - custom_accuracy: 0.9643 - val_loss: 0.2684 - val_custom_accuracy: 0.9167
# Epoch 4/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1947 - custom_accuracy: 0.9643 - val_loss: 0.1937 - val_custom_accuracy: 0.9583
# Epoch 5/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1712 - custom_accuracy: 0.9732 - val_loss: 0.2023 - val_custom_accuracy: 0.9792
# Epoch 6/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1777 - custom_accuracy: 0.9643 - val_loss: 0.2019 - val_custom_accuracy: 0.9583
# Epoch 7/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1654 - custom_accuracy: 0.9643 - val_loss: 0.2163 - val_custom_accuracy: 0.9583
# Epoch 8/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1745 - custom_accuracy: 0.9821 - val_loss: 0.2573 - val_custom_accuracy: 0.9167
# Epoch 9/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1933 - custom_accuracy: 0.9911 - val_loss: 0.2099 - val_custom_accuracy: 0.9583
# Epoch 10/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1851 - custom_accuracy: 0.9643 - val_loss: 0.2062 - val_custom_accuracy: 0.9792
# Epoch 11/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1930 - custom_accuracy: 0.9732 - val_loss: 0.2269 - val_custom_accuracy: 0.9375
# Epoch 12/25
# 7/7 [==============================] - 10s 2s/step - loss: 0.1735 - custom_accuracy: 0.9732 - val_loss: 0.2211 - val_custom_accuracy: 0.9583
# Epoch 13/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1689 - custom_accuracy: 0.9821 - val_loss: 0.2259 - val_custom_accuracy: 0.9167
# Epoch 14/25
# 7/7 [==============================] - 10s 1s/step - loss: 0.1688 - custom_accuracy: 0.9821 - val_loss: 0.2007 - val_custom_accuracy: 0.9375
# Epoch 15/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1633 - custom_accuracy: 1.0000 - val_loss: 0.2193 - val_custom_accuracy: 0.9375
# Epoch 16/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1817 - custom_accuracy: 0.9821 - val_loss: 0.2227 - val_custom_accuracy: 0.9167
# Epoch 17/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1648 - custom_accuracy: 0.9911 - val_loss: 0.2102 - val_custom_accuracy: 0.9375
# Epoch 18/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1724 - custom_accuracy: 0.9732 - val_loss: 0.2314 - val_custom_accuracy: 0.9583
# Epoch 19/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.1647 - custom_accuracy: 0.9643 - val_loss: 0.2389 - val_custom_accuracy: 0.9375
# Epoch 20/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1651 - custom_accuracy: 0.9821 - val_loss: 0.2396 - val_custom_accuracy: 0.9375
# Epoch 21/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1657 - custom_accuracy: 0.9732 - val_loss: 0.2463 - val_custom_accuracy: 0.8958
# Epoch 22/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.1543 - custom_accuracy: 0.9821 - val_loss: 0.2216 - val_custom_accuracy: 0.9375
# Epoch 23/25
# 7/7 [==============================] - 9s 1s/step - loss: 0.1543 - custom_accuracy: 0.9911 - val_loss: 0.2154 - val_custom_accuracy: 0.9583
# Epoch 24/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.1513 - custom_accuracy: 1.0000 - val_loss: 0.2319 - val_custom_accuracy: 0.9375
# Epoch 25/25
# 7/7 [==============================] - 8s 1s/step - loss: 0.1635 - custom_accuracy: 0.9911 - val_loss: 0.2324 - val_custom_accuracy: 0.9375

# %%
plt.plot(history.history['val_custom_accuracy'][:25], label='QCNN')
plt.plot(hybrid_history.history['val_custom_accuracy'][:25], label='Hybrid CNN')
plt.plot(multi_qconv_history.history['val_custom_accuracy'][:25],
         label='Hybrid CNN \n Multiple Quantum Filters')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4029068e-263e-4c12-9932-d3ac72036324' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
